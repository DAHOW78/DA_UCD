# %%
import pandas as pd

# %%
data=pd.read_csv("TravelInsurancePrediction.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  Age               Employment Type GraduateOrNot  AnnualIncome  \
# 0           0   31             Government Sector           Yes        400000
# 1           1   31  Private Sector/Self Employed           Yes       1250000
# 2           2   34  Private Sector/Self Employed           Yes        500000
# 3           3   28  Private Sector/Self Employed           Yes        700000
# 4           4   28  Private Sector/Self Employed           Yes        700000
#
#    FamilyMembers  ChronicDiseases FrequentFlyer EverTravelledAbroad  \
# 0              6                1            No                  No
# 1              7                0            No                  No
# 2              4                1            No                  No
# 3              3                1            No                  No
# 4              8                1           Yes                  No
#
#    TravelInsurance
# 0                0
# 1                0
# 2                1
# ...

# %%
data.sort_values("Age")
# Out:
#       Unnamed: 0  Age               Employment Type GraduateOrNot  \
# 1456        1456   25  Private Sector/Self Employed            No
# 1244        1244   25  Private Sector/Self Employed            No
# 595          595   25  Private Sector/Self Employed            No
# 592          592   25  Private Sector/Self Employed           Yes
# 1013        1013   25  Private Sector/Self Employed            No
# ...          ...  ...                           ...           ...
# 568          568   35  Private Sector/Self Employed            No
# 1184        1184   35  Private Sector/Self Employed            No
# 588          588   35  Private Sector/Self Employed            No
# 1885        1885   35             Government Sector           Yes
# 1690        1690   35  Private Sector/Self Employed            No
#
#       AnnualIncome  FamilyMembers  ChronicDiseases FrequentFlyer  \
# 1456       1700000              3                0           Yes
# ...

# %%
data.sort_values("GraduateOrNot",ascending=False)
# Out:
#       Unnamed: 0  Age               Employment Type GraduateOrNot  \
# 0              0   31             Government Sector           Yes
# 1281        1281   29             Government Sector           Yes
# 1279        1279   29  Private Sector/Self Employed           Yes
# 1277        1277   34  Private Sector/Self Employed           Yes
# 1276        1276   31             Government Sector           Yes
# ...          ...  ...                           ...           ...
# 211          211   27  Private Sector/Self Employed            No
# 617          617   30  Private Sector/Self Employed            No
# 1260        1260   30  Private Sector/Self Employed            No
# 1096        1096   30  Private Sector/Self Employed            No
# 263          263   35  Private Sector/Self Employed            No
#
#       AnnualIncome  FamilyMembers  ChronicDiseases FrequentFlyer  \
# 0           400000              6                1            No
# ...

# %%
data.sort_values(["Employment Type","AnnualIncome"])
# Out:
#       Unnamed: 0  Age               Employment Type GraduateOrNot  \
# 31            31   31             Government Sector            No
# 36            36   31             Government Sector            No
# 53            53   28             Government Sector           Yes
# 69            69   31             Government Sector            No
# 87            87   28             Government Sector           Yes
# ...          ...  ...                           ...           ...
# 1983        1983   28  Private Sector/Self Employed           Yes
# 346          346   25  Private Sector/Self Employed           Yes
# 1123        1123   25  Private Sector/Self Employed           Yes
# 1650        1650   25  Private Sector/Self Employed           Yes
# 1823        1823   25  Private Sector/Self Employed           Yes
#
#       AnnualIncome  FamilyMembers  ChronicDiseases FrequentFlyer  \
# 31          300000              4                0            No
# ...

# %%
data.sort_values(["Employment Type","AnnualIncome"], ascending=[True,False])
# Out:
#       Unnamed: 0  Age               Employment Type GraduateOrNot  \
# 654          654   32             Government Sector           Yes
# 1366        1366   31             Government Sector            No
# 1534        1534   33             Government Sector           Yes
# 1955        1955   33             Government Sector           Yes
# 13            13   31             Government Sector           Yes
# ...          ...  ...                           ...           ...
# 1607        1607   29  Private Sector/Self Employed           Yes
# 1668        1668   29  Private Sector/Self Employed           Yes
# 1810        1810   27  Private Sector/Self Employed            No
# 1844        1844   27  Private Sector/Self Employed            No
# 1879        1879   27  Private Sector/Self Employed            No
#
#       AnnualIncome  FamilyMembers  ChronicDiseases FrequentFlyer  \
# 654        1750000              6                0            No
# ...

# %%
data["Age"]
# Out:
# 0       31
# 1       31
# 2       34
# 3       28
# 4       28
#         ..
# 1982    33
# 1983    28
# 1984    28
# 1985    34
# 1986    34
# Name: Age, Length: 1987, dtype: int64

# %%
data[["Age", "AnnualIncome"]]
# Out:
#       Age  AnnualIncome
# 0      31        400000
# 1      31       1250000
# 2      34        500000
# 3      28        700000
# 4      28        700000
# ...   ...           ...
# 1982   33       1500000
# 1983   28       1750000
# 1984   28       1150000
# 1985   34       1000000
# 1986   34        500000
#
# [1987 rows x 2 columns]

# %%
data["Age"]>30
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 1982     True
# 1983    False
# 1984    False
# 1985     True
# 1986     True
# Name: Age, Length: 1987, dtype: bool

# %%
data[data["Age"]<30]
# Out:
#       Unnamed: 0  Age               Employment Type GraduateOrNot  \
# 3              3   28  Private Sector/Self Employed           Yes
# 4              4   28  Private Sector/Self Employed           Yes
# 5              5   25  Private Sector/Self Employed            No
# 8              8   28  Private Sector/Self Employed           Yes
# 11            11   26  Private Sector/Self Employed           Yes
# ...          ...  ...                           ...           ...
# 1979        1979   28  Private Sector/Self Employed           Yes
# 1980        1980   25  Private Sector/Self Employed            No
# 1981        1981   27             Government Sector           Yes
# 1983        1983   28  Private Sector/Self Employed           Yes
# 1984        1984   28  Private Sector/Self Employed           Yes
#
#       AnnualIncome  FamilyMembers  ChronicDiseases FrequentFlyer  \
# 3           700000              3                1            No
# ...

# %%
data[data["Employment Type"]=="Government Sector"]
# Out:
#       Unnamed: 0  Age    Employment Type GraduateOrNot  AnnualIncome  \
# 0              0   31  Government Sector           Yes        400000
# 6              6   31  Government Sector           Yes       1300000
# 9              9   33  Government Sector           Yes        800000
# 10            10   31  Government Sector           Yes        400000
# 12            12   32  Government Sector           Yes        850000
# ...          ...  ...                ...           ...           ...
# 1963        1963   33  Government Sector           Yes       1100000
# 1964        1964   28  Government Sector           Yes       1100000
# 1968        1968   28  Government Sector           Yes        300000
# 1976        1976   32  Government Sector           Yes        900000
# 1981        1981   27  Government Sector           Yes        850000
#
#       FamilyMembers  ChronicDiseases FrequentFlyer EverTravelledAbroad  \
# ...

# %%
data[(data["Employment Type"]=="Government Sector")&(data["FrequentFlyer"]=="Yes")]
# Out:
#       Unnamed: 0  Age    Employment Type GraduateOrNot  AnnualIncome  \
# 9              9   33  Government Sector           Yes        800000
# 13            13   31  Government Sector           Yes       1500000
# 24            24   31  Government Sector           Yes       1500000
# 61            61   32  Government Sector           Yes        800000
# 93            93   33  Government Sector           Yes        700000
# ...          ...  ...                ...           ...           ...
# 1897        1897   35  Government Sector           Yes       1100000
# 1935        1935   33  Government Sector           Yes       1000000
# 1946        1946   32  Government Sector           Yes        850000
# 1947        1947   32  Government Sector           Yes        900000
# 1952        1952   31  Government Sector           Yes       1500000
#
#       FamilyMembers  ChronicDiseases FrequentFlyer EverTravelledAbroad  \
# ...

# %%
is_yes_or_no=data["EverTravelledAbroad"].isin(["Yes","No"])
data[is_yes_or_no]
# Out:
#       Unnamed: 0  Age               Employment Type GraduateOrNot  \
# 0              0   31             Government Sector           Yes
# 1              1   31  Private Sector/Self Employed           Yes
# 2              2   34  Private Sector/Self Employed           Yes
# 3              3   28  Private Sector/Self Employed           Yes
# 4              4   28  Private Sector/Self Employed           Yes
# ...          ...  ...                           ...           ...
# 1982        1982   33  Private Sector/Self Employed           Yes
# 1983        1983   28  Private Sector/Self Employed           Yes
# 1984        1984   28  Private Sector/Self Employed           Yes
# 1985        1985   34  Private Sector/Self Employed           Yes
# 1986        1986   34  Private Sector/Self Employed           Yes
#
#       AnnualIncome  FamilyMembers  ChronicDiseases FrequentFlyer  \
# 0           400000              6                1            No
# ...
