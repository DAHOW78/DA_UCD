# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("500_Person_Gender_Height_Weight_Index.csv")

# %%
data
# Out:
#      Gender  Height  Weight  Index
# 0      Male     174      96      4
# 1      Male     189      87      2
# 2    Female     185     110      4
# 3    Female     195     104      3
# 4      Male     149      61      3
# ..      ...     ...     ...    ...
# 495  Female     150     153      5
# 496  Female     184     121      4
# 497  Female     141     136      5
# 498    Male     150      95      5
# 499    Male     173     131      5
#
# [500 rows x 4 columns]

# %%
height_cm=[174,189,185,195,140,150,184,141,150,173]
np_height_cm=np.array(height_cm)
print(np_height_cm)
# Out:
# [174 189 185 195 140 150 184 141 150 173]

# %%
weight_lb=[96,87,110,104,61,153,121,136,95,131]
np_weight_lb=np.array(weight_lb)
print(np_weight_lb)
# Out:
# [ 96  87 110 104  61 153 121 136  95 131]

# %%
np_weight_kg=np_weight_lb/2.205
print(np_weight_kg)
# Out:
# [43.53741497 39.45578231 49.88662132 47.16553288 27.66439909 69.3877551
#  54.87528345 61.67800454 43.08390023 59.41043084]

# %%
np_height_cm=np.array(height_cm)
np_weight_kg=np.array(weight_lb)/2.205
bmi=np_weight_kg/np_height_m**2*10000
print(bmi)
# Out:
# [14.38017405 11.04554249 14.57607635 12.40382193 14.11448933 30.83900227
#  16.20843675 31.02359264 19.1484001  19.85045636]

# %%
np_height_cm=np.array(height_cm)
print(np_height_cm.shape)
# Out:
# (10,)

# %%
np_data=np.array(data)
print(np_data[10,:])
# Out:
# ['Male' 195 81 2]

# %%
np_height_cm=np.array(height_cm)
print(np.mean(np_height_cm))
# Out:
# 168.1

# %%
print(np.median(np_height_cm))
# Out:
# 173.5

# %%
np_2d=np.array([[174,189,185,195],[97,87,110,104]])
np_2d
# Out:
# array([[174, 189, 185, 195],
#        [ 97,  87, 110, 104]])

# %%
np_2d.shape
# Out:
# (2, 4)

# %%
height=[174,189,18,195]
np.mean(height)
# Out:
# 144.0

# %%
height=[174,189,18,195]
np.median(height)
# Out:
# 181.5

# %%
height=[174,189,18,195]
np.std(height)
# Out:
# 73.14711204141965

# %%
np_height_cm=np.array(height_cm)
np_weight_lb=np.array(weight_lb)
meas=np.array([np_height_cm,np_weight_lb])
for val in meas:
    print(val)
# Out:
# [174 189 185 195 140 150 184 141 150 173]
# [ 96  87 110 104  61 153 121 136  95 131]

# %%
np_height_cm=np.array(height_cm)
for x in np_height_cm:
    print(str(x)+"centimetres")
# Out:
# 174centimetres
# 189centimetres
# 185centimetres
# 195centimetres
# 140centimetres
# 150centimetres
# 184centimetres
# 141centimetres
# 150centimetres
# 173centimetres

# %%
for val in data:
    print(val)
# Out:
# Gender
# Height
# Weight
# Index

# %%
for lab, row in data.iterrows():
    print(lab)
    print(row)
# Out:
# 0
# Gender    Male
# Height     174
# Weight      96
# Index        4
# Name: 0, dtype: object
# 1
# Gender    Male
# Height     189
# Weight      87
# Index        2
# Name: 1, dtype: object
# 2
# Gender    Female
# Height       185
# Weight       110
# Index          4
# Name: 2, dtype: object
# 3
# Gender    Female
# Height       195
# Weight       104
# Index          3
# Name: 3, dtype: object
# 4
# Gender    Male
# Height     149
# Weight      61
# Index        3
# Name: 4, dtype: object
# 5
# Gender    Male
# Height     189
# Weight     104
# Index        3
# Name: 5, dtype: object
# 6
# Gender    Male
# Height     147
# Weight      92
# Index        5
# Name: 6, dtype: object
# 7
# Gender    Male
# Height     154
# Weight     111
# Index        5
# Name: 7, dtype: object
# 8
# Gender    Male
# Height     174
# Weight      90
# Index        3
# Name: 8, dtype: object
# 9
# Gender    Female
# Height       169
# Weight       103
# Index          4
# Name: 9, dtype: object
# 10
# ...

# %%
import pandas as pd
data=pd.read_csv("500_Person_Gender_Height_Weight_Index.csv",index_col=0)
for lab, row in data.iterrows():
    print(lab +": "+ str(row["Weight"]))
# Out:
# Male: 96
# Male: 87
# Female: 110
# Female: 104
# Male: 61
# Male: 104
# Male: 92
# Male: 111
# Male: 90
# Female: 103
# Male: 81
# Female: 80
# Female: 101
# Male: 51
# Male: 79
# Female: 107
# Female: 110
# Male: 129
# Male: 145
# Male: 139
# Male: 110
# Female: 149
# Female: 97
# Male: 139
# Female: 67
# Female: 64
# Male: 95
# Male: 62
# Female: 159
# Male: 152
# Male: 121
# Male: 52
# Female: 65
# Female: 131
# Female: 153
# Female: 132
# Female: 114
# Male: 80
# Female: 152
# Female: 81
# Female: 120
# Female: 108
# Male: 56
# Male: 118
# Female: 126
# Male: 76
# Female: 122
# Male: 111
# Male: 72
# Male: 152
# Female: 135
# Female: 54
# Male: 110
# Male: 105
# Male: 116
# Female: 89
# Male: 92
# Male: 127
# Female: 70
# Male: 88
# Female: 54
# Female: 143
# Male: 54
# Male: 83
# Male: 135
# Female: 158
# Female: 96
# Female: 59
# Female: 82
# Female: 136
# Female: 51
# Male: 117
# Male: 80
# Male: 75
# Female: 100
# Female: 154
# Male: 104
# Female: 90
# Female: 122
# ...
