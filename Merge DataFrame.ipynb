# %%
import pandas as pd

# %%
data=pd.read_csv("Data-Melbourne_F.csv")

# %%
data
# Out:
#       avg_outflow  avg_inflow  total_grid    Am    BOD     COD      TN     T  \
# 0           2.941       2.589      175856  27.0  365.0   730.0  60.378  19.3
# 1           2.936       2.961      181624  25.0  370.0   740.0  60.026  17.1
# 2           2.928       3.225      202016  42.0  418.0   836.0  64.522  16.8
# 3           2.928       3.354      207547  36.0  430.0   850.0  63.000  14.6
# 4           2.917       3.794      202824  46.0  508.0  1016.0  65.590  13.4
# ...           ...         ...         ...   ...    ...     ...     ...   ...
# 1377        5.068       4.716      305938  28.0  310.0   660.0  58.807   6.8
# 1378        5.882       5.510      293446  40.0  250.0   700.0  60.671   7.6
# 1379        4.638       4.811      307968  47.0  260.0   860.0  64.000   9.7
# 1380        5.373       4.929      316675  46.0  300.0   900.0  62.479  10.9
# 1381        4.072       5.194      318268  31.0  270.0   910.0  63.312  12.4
#
# ...

# %%
data2=pd.read_csv("Data-Melbourne_F_fixed.csv")

# %%
data2
# Out:
#       Unnamed: 0  Average Outflow  Average Inflow  Energy Consumption  \
# 0              0            2.941           2.589            175856.0
# 1              1            2.936           2.961            181624.0
# 2              2            2.928           3.225            202016.0
# 3              3            2.928           3.354            207547.0
# 4              4            2.917           3.794            202824.0
# ...          ...              ...             ...                 ...
# 1377        1377            5.068           4.716            305938.0
# 1378        1378            5.882           5.510            293446.0
# 1379        1379            4.638           4.811            307968.0
# 1380        1380            5.373           4.929            316675.0
# 1381        1381            4.072           5.194            318268.0
#
#       Ammonia  Biological Oxygen Demand  Chemical Oxygen Demand  \
# ...

# %%
data_data2=data.merge(data, on="year")
print(data_data2.head())
# Out:
#    avg_outflow_x  avg_inflow_x  total_grid_x  Am_x  BOD_x  COD_x    TN_x  \
# 0          2.941         2.589        175856  27.0  365.0  730.0  60.378
# 1          2.941         2.589        175856  27.0  365.0  730.0  60.378
# 2          2.941         2.589        175856  27.0  365.0  730.0  60.378
# 3          2.941         2.589        175856  27.0  365.0  730.0  60.378
# 4          2.941         2.589        175856  27.0  365.0  730.0  60.378
#
#     T_x  TM_x  Tm_x  ...  Tm_y  SLP_y  H_y  PP_y  VV_y   V_y  VM_y  VG_y  \
# 0  19.3  25.1  12.6  ...  12.6    0.0   56  1.52  10.0  26.9  53.5  79.5
# 1  19.3  25.1  12.6  ...  12.3    0.0   63  0.00  10.0  14.4  27.8   0.0
# 2  19.3  25.1  12.6  ...   8.8    0.0   47  0.25  10.0  31.9  61.1  77.8
# 3  19.3  25.1  12.6  ...  11.1    0.0   49  0.00  10.0  27.0  38.9  53.5
# 4  19.3  25.1  12.6  ...   8.0    0.0   65  0.00  10.0  20.6  35.2  53.5
#
#    month_y  day_y
# 0        1      1
# 1        1      2
# 2        1      5
# ...

# %%
print(data_data2.columns)
# Out:
# Index(['avg_outflow_x', 'avg_inflow_x', 'total_grid_x', 'Am_x', 'BOD_x',
#        'COD_x', 'TN_x', 'T_x', 'TM_x', 'Tm_x', 'SLP_x', 'H_x', 'PP_x', 'VV_x',
#        'V_x', 'VM_x', 'VG_x', 'year', 'month_x', 'day_x', 'avg_outflow_y',
#        'avg_inflow_y', 'total_grid_y', 'Am_y', 'BOD_y', 'COD_y', 'TN_y', 'T_y',
#        'TM_y', 'Tm_y', 'SLP_y', 'H_y', 'PP_y', 'VV_y', 'V_y', 'VM_y', 'VG_y',
#        'month_y', 'day_y'],
#       dtype='object')

# %%
data_data2=data.merge(data, on=["year","month","day"])
print(data_data2)
# Out:
#       avg_outflow_x  avg_inflow_x  total_grid_x  Am_x  BOD_x   COD_x    TN_x  \
# 0             2.941         2.589        175856  27.0  365.0   730.0  60.378
# 1             2.936         2.961        181624  25.0  370.0   740.0  60.026
# 2             2.928         3.225        202016  42.0  418.0   836.0  64.522
# 3             2.928         3.354        207547  36.0  430.0   850.0  63.000
# 4             2.917         3.794        202824  46.0  508.0  1016.0  65.590
# ...             ...           ...           ...   ...    ...     ...     ...
# 1377          5.068         4.716        305938  28.0  310.0   660.0  58.807
# 1378          5.882         5.510        293446  40.0  250.0   700.0  60.671
# 1379          4.638         4.811        307968  47.0  260.0   860.0  64.000
# 1380          5.373         4.929        316675  46.0  300.0   900.0  62.479
# 1381          4.072         5.194        318268  31.0  270.0   910.0  63.312
#
# ...
