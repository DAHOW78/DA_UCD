# %%
import pandas as pd

# %%
wine=pd.read_csv("wines_SPA.csv")

# %%
wine
# Out:
#                     winery             wine  year  rating  num_reviews  \
# 0            Teso La Monja            Tinto  2013     4.9           58
# 1                   Artadi    Vina El Pison  2018     4.9           31
# 2             Vega Sicilia            Unico  2009     4.8         1793
# 3             Vega Sicilia            Unico  1999     4.8         1705
# 4             Vega Sicilia            Unico  1996     4.8         1309
# ...                    ...              ...   ...     ...          ...
# 7495               Contino          Reserva  2016     4.2          392
# 7496  Conreria d'Scala Dei    Les Brugueres  2018     4.2          390
# 7497           Mustiguillo  Finca Terrerazo  2017     4.2          390
# 7498           Matarromera     Gran Reserva  2011     4.2          389
# 7499              Sei Solo         Preludio  2016     4.2          388
#
#      country            region   price                  type  body  acidity
# ...

# %%
wine_ind=wine.set_index("wine")
print(wine_ind)
# Out:
#                                winery  year  rating  num_reviews country  \
# wine
# Tinto                   Teso La Monja  2013     4.9           58  Espana
# Vina El Pison                  Artadi  2018     4.9           31  Espana
# Unico                    Vega Sicilia  2009     4.8         1793  Espana
# Unico                    Vega Sicilia  1999     4.8         1705  Espana
# Unico                    Vega Sicilia  1996     4.8         1309  Espana
# ...                               ...   ...     ...          ...     ...
# Reserva                       Contino  2016     4.2          392  Espana
# Les Brugueres    Conreria d'Scala Dei  2018     4.2          390  Espana
# Finca Terrerazo           Mustiguillo  2017     4.2          390  Espana
# Gran Reserva              Matarromera  2011     4.2          389  Espana
# Preludio                     Sei Solo  2016     4.2          388  Espana
#
#                            region   price                  type  body  acidity
# wine
# ...

# %%
wine_ind=wine_ind.reset_index()
print(wine_ind)
# Out:
#                  wine                winery  year  rating  num_reviews  \
# 0               Tinto         Teso La Monja  2013     4.9           58
# 1       Vina El Pison                Artadi  2018     4.9           31
# 2               Unico          Vega Sicilia  2009     4.8         1793
# 3               Unico          Vega Sicilia  1999     4.8         1705
# 4               Unico          Vega Sicilia  1996     4.8         1309
# ...               ...                   ...   ...     ...          ...
# 7495          Reserva               Contino  2016     4.2          392
# 7496    Les Brugueres  Conreria d'Scala Dei  2018     4.2          390
# 7497  Finca Terrerazo           Mustiguillo  2017     4.2          390
# 7498     Gran Reserva           Matarromera  2011     4.2          389
# 7499         Preludio              Sei Solo  2016     4.2          388
#
#      country            region   price                  type  body  acidity
# ...

# %%
wine_ind.reset_index(drop=True)
print(wine_ind)
# Out:
#                  wine                winery  year  rating  num_reviews  \
# 0               Tinto         Teso La Monja  2013     4.9           58
# 1       Vina El Pison                Artadi  2018     4.9           31
# 2               Unico          Vega Sicilia  2009     4.8         1793
# 3               Unico          Vega Sicilia  1999     4.8         1705
# 4               Unico          Vega Sicilia  1996     4.8         1309
# ...               ...                   ...   ...     ...          ...
# 7495          Reserva               Contino  2016     4.2          392
# 7496    Les Brugueres  Conreria d'Scala Dei  2018     4.2          390
# 7497  Finca Terrerazo           Mustiguillo  2017     4.2          390
# 7498     Gran Reserva           Matarromera  2011     4.2          389
# 7499         Preludio              Sei Solo  2016     4.2          388
#
#      country            region   price                  type  body  acidity
# ...

# %%
wine[wine["wine"].isin(["Tinto","Unico"])]
# Out:
#                        winery   wine  year  rating  num_reviews country  \
# 0               Teso La Monja  Tinto  2013     4.9           58  Espana
# 2                Vega Sicilia  Unico  2009     4.8         1793  Espana
# 3                Vega Sicilia  Unico  1999     4.8         1705  Espana
# 4                Vega Sicilia  Unico  1996     4.8         1309  Espana
# 5                Vega Sicilia  Unico  1998     4.8         1209  Espana
# ...                       ...    ...   ...     ...          ...     ...
# 1706  Espectacle del Montsant  Tinto  2018     4.3           39  Espana
# 1729             Real de Asua  Tinto  2000     4.3           36  Espana
# 1796        Rodriguez de Vera  Tinto  2017     4.3           27  Espana
# 1805                    Loess  Tinto  2019     4.3           26  Espana
# 1983                 Valderiz  Tinto  2018     4.2          481  Espana
#
#                 region   price                  type  body  acidity
# ...

# %%
wine_ind2=wine.set_index("winery")
print(wine_ind2)
# Out:
#                                  wine  year  rating  num_reviews country  \
# winery
# Teso La Monja                   Tinto  2013     4.9           58  Espana
# Artadi                  Vina El Pison  2018     4.9           31  Espana
# Vega Sicilia                    Unico  2009     4.8         1793  Espana
# Vega Sicilia                    Unico  1999     4.8         1705  Espana
# Vega Sicilia                    Unico  1996     4.8         1309  Espana
# ...                               ...   ...     ...          ...     ...
# Contino                       Reserva  2016     4.2          392  Espana
# Conreria d'Scala Dei    Les Brugueres  2018     4.2          390  Espana
# Mustiguillo           Finca Terrerazo  2017     4.2          390  Espana
# Matarromera              Gran Reserva  2011     4.2          389  Espana
# Sei Solo                     Preludio  2016     4.2          388  Espana
#
#                                 region   price                  type  body  \
# ...

# %%
wine_ind2.loc["Vega Sicilia"]
# Out:
#                      wine  year  rating  num_reviews country  \
# winery
# Vega Sicilia        Unico  2009     4.8         1793  Espana
# Vega Sicilia        Unico  1999     4.8         1705  Espana
# Vega Sicilia        Unico  1996     4.8         1309  Espana
# Vega Sicilia        Unico  1998     4.8         1209  Espana
# Vega Sicilia        Unico  2010     4.8         1201  Espana
# ...                   ...   ...     ...          ...     ...
# Vega Sicilia  Valbuena 5o  1976     4.5           37  Espana
# Vega Sicilia  Valbuena 5o  1975     4.5           31  Espana
# Vega Sicilia  Valbuena 5o  1995     4.4          512  Espana
# Vega Sicilia  Valbuena 5o  1994     4.4          218  Espana
# Vega Sicilia  Valbuena 5o  1982     4.4           56  Espana
#
#                         region   price                  type  body  acidity
# winery
# Vega Sicilia  Ribera del Duero  324.95  Ribera Del Duero Red   5.0      3.0
# ...

# %%
wine_ind3=wine.set_index(["winery","year"])
print(wine_ind3)
# Out:
#                                       wine  rating  num_reviews country  \
# winery               year
# Teso La Monja        2013            Tinto     4.9           58  Espana
# Artadi               2018    Vina El Pison     4.9           31  Espana
# Vega Sicilia         2009            Unico     4.8         1793  Espana
#                      1999            Unico     4.8         1705  Espana
#                      1996            Unico     4.8         1309  Espana
# ...                                    ...     ...          ...     ...
# Contino              2016          Reserva     4.2          392  Espana
# Conreria d'Scala Dei 2018    Les Brugueres     4.2          390  Espana
# Mustiguillo          2017  Finca Terrerazo     4.2          390  Espana
# Matarromera          2011     Gran Reserva     4.2          389  Espana
# Sei Solo             2016         Preludio     4.2          388  Espana
#
#                                      region   price                  type  \
# ...

# %%
wine_ind3.sort_index()
# Out:
#                                                                             wine  \
# winery                           year
# A Coroa                          2020                         200 Cestos Godello
# AGE                              1959                     Fuenmayor Gran Reserva
# Aalto                            2011  PS (Pagos Seleccionados) Ribera del Duero
#                                  2012                                      Tinto
#                                  2015  PS (Pagos Seleccionados) Ribera del Duero
# ...                                                                          ...
# Ysios                            2017                              Grano a Grano
# Zarate                           2018                      Tras da Vina Albarino
# Zifar                            2016                        Pago de las Sabinas
#                                  2020                  Senda de Los Olivos Roble
# ...

# %%
wine_srt=wine.set_index(["winery","year"]).sort_index()
print(wine_srt)
# Out:
#                                                                             wine  \
# winery                           year
# A Coroa                          2020                         200 Cestos Godello
# AGE                              1959                     Fuenmayor Gran Reserva
# Aalto                            2011  PS (Pagos Seleccionados) Ribera del Duero
#                                  2012                                      Tinto
#                                  2015  PS (Pagos Seleccionados) Ribera del Duero
# ...                                                                          ...
# Ysios                            2017                              Grano a Grano
# Zarate                           2018                      Tras da Vina Albarino
# Zifar                            2016                        Pago de las Sabinas
#                                  2020                  Senda de Los Olivos Roble
# ...

# %%
wine_srt.loc["A Coroa":"AGE"]
# Out:
#                                 wine  rating  num_reviews country      region  \
# winery  year
# A Coroa 2020      200 Cestos Godello     4.3           33  Espana  Valdeorras
# AGE     1959  Fuenmayor Gran Reserva     4.3           29  Espana       Rioja
#
#               price       type  body  acidity
# winery  year
# A Coroa 2020   23.7        NaN   NaN      NaN
# AGE     1959  230.0  Rioja Red   4.0      3.0

# %%
wine_srt.loc[:, "region":"country"]
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
print(wine.iloc[:2])
# Out:
#           winery           wine  year  rating  num_reviews country  \
# 0  Teso La Monja          Tinto  2013     4.9           58  Espana
# 1         Artadi  Vina El Pison  2018     4.9           31  Espana
#
#            region  price         type  body  acidity
# 0            Toro  995.0     Toro Red   5.0      3.0
# 1  Vino de Espana  313.5  Tempranillo   4.0      2.0
